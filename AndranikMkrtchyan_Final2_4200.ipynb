# %% [markdown]
# # Simple Differential equation
# Using a Euler differential equation and using the base of the zombie code, I made a simple differential equation code that shows an interesting graph of peaks.

# %%
# zombie apocalypse modeling
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from scipy.integrate import odeint
plt.ion()
plt.rcParams['figure.figsize'] = 10, 8

t = 2       # birth rate
w = 5  # natural death percent (per day)
v = 3
x = 6

# solve the system dy/dt = f(y, t)
def f(y, t):
     Si = y[0] #S
     Zi = y[1] #Z
     Ri = y[2] #R
     f0 = 3+(3+(Si*t)-w)**3
     f1 = 4+(2+(Zi*t)-v)**4
     f2 = 5+(1+(Ri*c)-x)**5
     return [f0, f1, f2]

# initial conditions
S0 = 5.              # initial S
Z0 = 3                 # initial Z
R0 = 2                # initial R
y0 = [S0, Z0, R0]     # initial condition vector
t  = np.linspace(0, 100., 1000)         # time grid

# solve the DEs
soln = odeint(f, y0, t)
S = soln[:, 0]
Z = soln[:, 1]
R = soln[:, 2]

# plot results
plt.figure()
plt.plot(t, S, label='S')
plt.plot(t, Z, label='Z')
plt.xlabel('Time')
plt.ylabel('Amount')
plt.legend(loc=0)

# change the initial conditions
R0 = 0.01*S0   # 1% of initial s
y0 = [S0, Z0, R0]

# solve the DEs
soln = odeint(f, y0, t)
S = soln[:, 0]
Z = soln[:, 1]
R = soln[:, 2]

plt.figure()
plt.plot(t, S, label='S')
plt.plot(t, Z, label='Z')
plt.xlabel('Time')
plt.ylabel('Amount')
plt.legend(loc=0)

# change the initial conditions
R0 = 0.01*S0   # 1% of initial S
P  = 10        # 10 new amount each unit of time
y0 = [S0, Z0, R0]

# solve the DEs
soln = odeint(f, y0, t)
S = soln[:, 0]
Z = soln[:, 1]
R = soln[:, 2]

plt.figure()
plt.plot(t, S, label='S')
plt.plot(t, Z, label='Z')
plt.xlabel('Time')
plt.ylabel('Amount')
plt.legend(loc=0)
# Out:
# C:\Users\Andranik Mkrtchyan\Anaconda3\lib\site-packages\scipy\integrate\odepack.py:218: ODEintWarning: Excess work done on this call (perhaps wrong Dfun type). Run with full_output = 1 to get quantitative information.
#   warnings.warn(warning_msg, ODEintWarning)
